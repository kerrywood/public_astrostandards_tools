# %% [markdown]
# # 01.Initialization
#
# Verify the initial setup of the required harnesses.

# %%
import public_astrostandards as PA
import public_astrostandards_tools as PAT

# %% [markdown]
# Check that the base harness is able to init and see the underlying libraries.

# %%
PA.get_versions()
# Out:
# AstroFuncDll                    HQ SpOC AstroFunc - Version: v9.6 - Build: Jun 11 2025 - Platform: Windows 64-bit - Compiler: OneAPI ifort
# DllMainDll                      HQ SpOC DllMain - Version: v9.6 - Build: Jun 11 2025 - Platform: Windows 64-bit - Compiler: OneAPI ifort
# ElOpsDll                        HQ SpOC ElOps - Version: v9.6 - Build: Jun 11 2025 - Platform: Windows 64-bit - Compiler: OneAPI ifort
# EnvConstDll                     HQ SpOC EnvConst - Version: v9.6 - Build: Jun 11 2025 - Platform: Windows 64-bit - Compiler: OneAPI ifort
# ExtEphemDll                     HQ SpOC ExtEphem - Version: v9.6 - Build: Jun 11 2025 - Platform: Windows 64-bit - Compiler: OneAPI ifort
# ObsDll                          HQ SpOC Obs - Version: v9.6 - Build: Jun 11 2025 - Platform: Windows 64-bit - Compiler: OneAPI ifort
# SatStateDll                     HQ SpOC SatState - Version: v9.6 - Build: Jun 11 2025 - Platform: Windows 64-bit - Compiler: OneAPI ifort
# ...

# %% [markdown]
# Pull the latest time constants file and update

# %%
new_time_constants = PAT.utils.pull_reduced_time_constants_github()
with open('./reduced_time_constants.dat','w') as F:
    F.write( new_time_constants )

# most public_astrostandard_tools calls will want you to pass in the harness to the call; note the last argument here
PAT.astro_time.load_time_constants( './reduced_time_constants.dat', PA )
# Out:
# C:\Users\1368355255E\ENV\TESTENV\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'asterism.ai'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
